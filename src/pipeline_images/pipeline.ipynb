# %%
# Parameters
kms_key = "arn:aws:kms:us-west-2:000000000000:1234abcd-12ab-34cd-56ef-1234567890ab"

# %%
import sys

# !{sys.executable} -m pip install "sagemaker>=2.99.0"
# Out:
# Requirement already satisfied: sagemaker>=2.99.0 in /opt/conda/lib/python3.12/site-packages (2.242.0)
# Requirement already satisfied: attrs<24,>=23.1.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.99.0) (23.2.0)
# Requirement already satisfied: boto3<2.0,>=1.35.75 in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.99.0) (1.37.1)
# Requirement already satisfied: cloudpickle>=2.2.1 in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.99.0) (3.1.1)
# Requirement already satisfied: docker in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.99.0) (7.1.0)
# Requirement already satisfied: fastapi in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.99.0) (0.115.12)
# Requirement already satisfied: google-pasta in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.99.0) (0.2.0)
# Requirement already satisfied: importlib-metadata<7.0,>=1.4.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.99.0) (6.10.0)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.99.0) (4.23.0)
# Requirement already satisfied: numpy<2.0,>=1.9.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.99.0) (1.26.4)
# Requirement already satisfied: omegaconf<=2.3,>=2.2 in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.99.0) (2.3.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.99.0) (24.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.99.0) (2.2.3)
# Requirement already satisfied: pathos in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.99.0) (0.3.4)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.99.0) (4.3.7)
# Requirement already satisfied: protobuf<6.0,>=3.12 in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.99.0) (5.28.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.99.0) (5.9.8)
# Requirement already satisfied: pyyaml~=6.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.99.0) (6.0.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.99.0) (2.32.3)
# Requirement already satisfied: sagemaker-core<2.0.0,>=1.0.17 in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.99.0) (1.0.31)
# Requirement already satisfied: schema in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.99.0) (0.7.7)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.99.0) (1.0.1)
# Requirement already satisfied: tblib<4,>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.99.0) (3.1.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.99.0) (4.67.1)
# Requirement already satisfied: urllib3<3.0.0,>=1.26.8 in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.99.0) (2.4.0)
# Requirement already satisfied: uvicorn in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.99.0) (0.34.2)
# Requirement already satisfied: botocore<1.38.0,>=1.37.1 in /opt/conda/lib/python3.12/site-packages (from boto3<2.0,>=1.35.75->sagemaker>=2.99.0) (1.37.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from boto3<2.0,>=1.35.75->sagemaker>=2.99.0) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /opt/conda/lib/python3.12/site-packages (from boto3<2.0,>=1.35.75->sagemaker>=2.99.0) (0.11.3)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker>=2.99.0) (3.21.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /opt/conda/lib/python3.12/site-packages (from omegaconf<=2.3,>=2.2->sagemaker>=2.99.0) (4.9.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker-core<2.0.0,>=1.0.17->sagemaker>=2.99.0) (2.11.3)
# Requirement already satisfied: rich<14.0.0,>=13.0.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker-core<2.0.0,>=1.0.17->sagemaker>=2.99.0) (13.9.4)
# Requirement already satisfied: mock<5.0,>4.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker-core<2.0.0,>=1.0.17->sagemaker>=2.99.0) (4.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.12/site-packages (from jsonschema->sagemaker>=2.99.0) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.12/site-packages (from jsonschema->sagemaker>=2.99.0) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from jsonschema->sagemaker>=2.99.0) (0.24.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->sagemaker>=2.99.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->sagemaker>=2.99.0) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests->sagemaker>=2.99.0) (2025.1.31)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /opt/conda/lib/python3.12/site-packages (from fastapi->sagemaker>=2.99.0) (0.46.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.12/site-packages (from fastapi->sagemaker>=2.99.0) (4.13.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.12/site-packages (from google-pasta->sagemaker>=2.99.0) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas->sagemaker>=2.99.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas->sagemaker>=2.99.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas->sagemaker>=2.99.0) (2025.2)
# Requirement already satisfied: ppft>=1.7.7 in /opt/conda/lib/python3.12/site-packages (from pathos->sagemaker>=2.99.0) (1.7.7)
# Requirement already satisfied: dill>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from pathos->sagemaker>=2.99.0) (0.4.0)
# Requirement already satisfied: pox>=0.3.6 in /opt/conda/lib/python3.12/site-packages (from pathos->sagemaker>=2.99.0) (0.3.6)
# Requirement already satisfied: multiprocess>=0.70.18 in /opt/conda/lib/python3.12/site-packages (from pathos->sagemaker>=2.99.0) (0.70.18)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.12/site-packages (from uvicorn->sagemaker>=2.99.0) (8.1.8)
# Requirement already satisfied: h11>=0.8 in /opt/conda/lib/python3.12/site-packages (from uvicorn->sagemaker>=2.99.0) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker>=2.99.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker>=2.99.0) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker>=2.99.0) (0.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.12/site-packages (from rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker>=2.99.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.12/site-packages (from rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker>=2.99.0) (2.19.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in /opt/conda/lib/python3.12/site-packages (from starlette<0.47.0,>=0.40.0->fastapi->sagemaker>=2.99.0) (4.9.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi->sagemaker>=2.99.0) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker>=2.99.0) (0.1.2)

# %%
import boto3
import sagemaker
from sagemaker.workflow.pipeline_context import PipelineSession

sagemaker_session = sagemaker.session.Session()
region = sagemaker_session.boto_region_name
role = sagemaker.get_execution_role()
pipeline_session = PipelineSession()
default_bucket = sagemaker_session.default_bucket()
default_bucket_prefix = sagemaker_session.default_bucket_prefix
default_bucket_prefix_path = ""
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml

# %%
# !mkdir -p data

# %%
# === S3 PARAMETERS ===
S3_BUCKET = "itam-analytics-thmrudolf"
S3_KEY = "final_project/clean/beer_names_breweries_with_images.csv"
# === local parameters
local_path = "data/beer_names_breweries_with_images.csv"

s3 = boto3.resource("s3")
s3.Bucket(f"{S3_BUCKET}").download_file(
    f"{S3_KEY}", local_path
)


base_uri = f"s3://{S3_BUCKET}/{S3_KEY}"
input_data_uri = sagemaker.s3.S3Uploader.upload(
    local_path=local_path,
    desired_s3_uri=base_uri,
)
print(input_data_uri)
# Out:
# s3://itam-analytics-thmrudolf/final_project/clean/beer_names_breweries_with_images.csv/beer_names_breweries_with_images.csv

# %%
# === CONFIGURATION ===
import json
with open("credentials_google_search.json", 'r') as f:
    creds = json.load(f)
GOOGLE_API_KEY = creds['google']['api_key']
GOOGLE_CSE_ID = creds['google']['cx']

# %%
# === INITIALIZATION ===
# Abres un cliente de S3
import boto3
from io import StringIO
import pandas as pd
from pipeline_actualization_images import add_image_url_column_if_not_exists, find_beer_image_url 
s3 = boto3.client('s3')  # sin profile_name

all_records = []

# === SEARCH LOOP ===
print("Starting image search...")
# Read the CSV from S3 bucket
db_beers_names_breweries = pd.read_csv(local_path)

db_beers = add_image_url_column_if_not_exists(db_beers_names_breweries,
                                              GOOGLE_API_KEY,
                                              GOOGLE_CSE_ID,
                                              s3, S3_BUCKET, S3_KEY)
#all_records = db_beers.to_dict(orient="records")

# === SAVE TO S3 ===
#print(f"Saving {len(all_records)} image URLs to S3...")

#df = pd.DataFrame(all_records)
#csv_buffer = StringIO()
#df.to_csv(csv_buffer, index=False)

#s3.put_object(Bucket=S3_BUCKET, Key=S3_KEY, Body=csv_buffer.getvalue())
#print(f"Done! Saved to s3://{S3_BUCKET}/{S3_KEY}")
# Out:
# Starting image search...
# Beer: amber, Brewery: alaskan brewing co.
# Skipping row 0, image_url already exists:
# https://tse2.mm.bing.net/th?id=OIP.p2UqLwq4WBWB4rhAdHq--gHaLO&pid=Api&P=0&h=180
# Beer: double bag, Brewery: long trail brewing co.
# Skipping row 1, image_url already exists:
# https://www.instacart.com/image-server/1200x1200/www.instacart.com/assets/domains/product-image/file/large_08cdae49-739c-44d8-beaf-be7849984cfa.jpg
# Beer: long trail ale, Brewery: long trail brewing co.
# Skipping row 2, image_url already exists:
# https://longtrail.com/wp-content/uploads/2022/06/LTB313-18-SummerAle-Rebrand-Bottle-3D-LR_1.png
# Beer: doppelsticke, Brewery: uerige obergarige hausbrauerei gmbh / zum uerige
# Skipping row 3, image_url already exists:
# https://www.bierverkostung.de/bilder_bier/4144_2020-07-25_Uerige_DoppelSticke.jpg
# Beer: sleigh'r dark double alt ale, Brewery: ninkasi brewing company
# Skipping row 4, image_url already exists:
# https://cdn.shopify.com/s/files/1/0227/0581/products/Ninkasi-Sleighr-Dark-Double-Alt-12OZ-BTL_535x.jpg?v=1605366678
# Beer: sticke, Brewery: uerige obergarige hausbrauerei gmbh / zum uerige
# Skipping row 5, image_url already exists:
# http://cdn.beeradvocate.com/im/beers/16146.jpg
# Beer: okto festival ale, Brewery: widmer brothers brewing company
# Skipping row 6, image_url already exists:
# https://imbibemagazine.com/wp-content/uploads/2012/09/Widmer-Okto.jpg
# Beer: southampton altbier, Brewery: southampton publick house
# Skipping row 7, image_url already exists:
# https://thefullpint.com/wp-content/uploads/2010/10/southampton-double-white.png
# Beer: copper, Brewery: the olde mecklenburg brewery
# Skipping row 8, image_url already exists:
# https://i.pinimg.com/originals/68/1c/11/681c115ce66b1ec3251d486f74b6e488.png
# Beer: organic munster alt, Brewery: brauerei pinkus mueller
# Skipping row 9, image_url already exists:
# https://merchantduvin.com/wp-content/uploads/2021/09/organic-munster-alt-1.png
# Beer: altbier, Brewery: uerige obergarige hausbrauerei gmbh / zum uerige
# Skipping row 10, image_url already exists:
# https://dingsbeerblog.com/wp-content/uploads/2006/03/uerigedoppel.png
# Beer: gerst amber, Brewery: yazoo brewing company
# Skipping row 11, image_url already exists:
# https://i0.wp.com/yazoobrew.com/wp-content/uploads/2023/06/Gerst_6-scaled.jpg?fit=1024%2C1024&ssl=1
# Beer: ad astra ale, Brewery: free state brewing co.
# Skipping row 12, image_url already exists:
# https://www.freestatebrewing.com/wp-content/uploads/2021/02/ad-astra-6-pack-5.png
# Beer: copperhead ale, Brewery: fordham brewing company
# Skipping row 13, image_url already exists:
# https://www.beermonthclub.com/media/catalog/product/cache/378672482a068cbb2cf82f9e8b9a0872/f/o/fordham-copperhead-ale-coa_1.jpg
# Beer: ten years alt, Brewery: victory brewing company
# Skipping row 14, image_url already exists:
# https://live.staticflickr.com/46/150726753_3324b1a3f1_b.jpg
# Beer: three blind mice, Brewery: mother's brewing company
# Skipping row 15, image_url already exists:
# https://www.mothersbrewing.com/wp-content/uploads/2024/06/Layer-1-ImageMothersDay.png
# Beer: ishmael, Brewery: rising tide brewing company
# Skipping row 16, image_url already exists:
# https://craftpeak-cooler-images.imgix.net/rising-tide-brewing/ishmael2_front-3.png?auto=compress%2Cformat&ixlib=php-3.3.1&s=d8f21a6bcdc20ca0f00f18bff92e31d5
# Beer: headwall alt, Brewery: tuckerman brewing co.
# Skipping row 17, image_url already exists:
# https://tuckermanbrewing.com/images/tb23/brews/headwall1-240625.jpg
# Beer: alt-eration ale, Brewery: hops & grain
# Skipping row 18, image_url already exists:
# https://img.cdn4dd.com/cdn-cgi/image/fit=contain,width=1200,height=672,format=auto/https://doordash-static.s3.amazonaws.com/media/photosV2/dd418d9e-5cae-44e2-a674-f6b5aac14356-retina-large.jpg
# Beer: schell's schmaltz's alt, Brewery: august schell brewing company
# Skipping row 19, image_url already exists:
# https://assets.untappd.com/site/beer_logos_hd/beer-11962_56929_hd.jpeg
# Beer: frankenheim alt, Brewery: privatbrauerei frankenheim
# Skipping row 20, image_url already exists:
# https://images.bierothek.de/storage/product_images/cat/FrankenheimAlt_213111.webp
# Beer: iron works alt, Brewery: metropolitan brewing
# Skipping row 21, image_url already exists:
# https://www.twobeerdudes.com/images/beers/iron_works_alt_metropolitan_brewing.jpg
# Beer: diebels premium altbier, Brewery: brauerei diebels gmbh & co kg
# Skipping row 22, image_url already exists:
# https://www.beersofeurope.co.uk/wp-content/uploads/2023/01/DiebelsAlt.jpg
# Beer: mission amber, Brewery: mission brewery
# Skipping row 23, image_url already exists:
# http://bevmo.com/cdn/shop/products/8cc8171c-2ba2-495a-abb4-dbbcc3d8bf38-background_removed.png?v=1709096987
# Beer: hovels original, Brewery: hovels hausbrauerei
# Skipping row 24, image_url already exists:
# https://i.ebayimg.com/images/g/lGsAAOSwoGJf59Yo/s-l1200.jpg
# Beer: secret spot alt ale, Brewery: evolution craft brewing company
# Skipping row 25, image_url already exists:
# https://shorecraftbeer.com/wp-content/uploads/2015/12/SS-and-Silky6.jpg
# Beer: lighthouse amber, Brewery: cheboygan brewing company
# Skipping row 26, image_url already exists:
# https://i5.walmartimages.com/seo/Cheboygan-Brewing-Company-Lighthouse-Amber-Ale-Beer-4-Pack-16-fl-oz-Cans_cf314243-1276-4458-9d7a-4a876683fbfa.b0dde4a17830b1389193036040f67d14.png?odnHeight=768&odnWidth=768&odnBg=FFFFFF
# Beer: serie signature sticke alt, Brewery: les trois mousquetaires
# Skipping row 27, image_url already exists:
# https://cdn.beeradvocate.com/im/beers/56209.jpg
# Beer: crooked coast altbier, Brewery: driftwood brewery
# Skipping row 28, image_url already exists:
# https://images.squarespace-cdn.com/content/v1/527bd1f5e4b0040d68c6af3c/1552496861310-A1KZKZUU6TJ0RP5USDDU/Packaging+Design+for+Driftwood+Brewery%27s+Crooked+Coast+Altbier
# Beer: gravel road, Brewery: rahr & sons brewing company
# Skipping row 29, image_url already exists:
# https://assets.untappd.com/photos/2023_02_01/ad9cf59c6426f6ca776411ff9cab9778_640x640.jpg
# Beer: little red cap, Brewery: grimm brothers brewhouse
# Skipping row 30, image_url already exists:
# https://files.elfsightcdn.com/eafe4a4d-3436-495d-b748-5bdce62d911d/9c75c616-ab19-4e1a-a64e-ddac904e9a88/little-red_grimm.png
# Beer: festivale, Brewery: beau's all natural brewing company
# Skipping row 31, image_url already exists:
# https://floridabeerblog.wordpress.com/wp-content/uploads/2016/03/wp-1457633080761.png
# Beer: moby d, Brewery: buzzards bay brewing
# Skipping row 32, image_url already exists:
# https://buzzardsbrew.com/wp-content/uploads/2019/05/Buzzards-Bay-Logo-250x250.png
# Beer: uber alt, Brewery: rush river brewing company
# Skipping row 33, image_url already exists:
# https://rushriverbeer.com/wp-content/uploads/2015/04/RR-bottle-uberalt_2.png
# Beer: fuchschen alt, Brewery: brauerei im fuchschen
# Skipping row 34, image_url already exists:
# https://mein.toubiz.de/api/v1/article/bef1a047-a9a9-4d4e-b3a3-cb60e5355689/mainImage?format=image/jpeg&width=1900
# Beer: sticke it to the man, Brewery: o'fallon brewery
# Skipping row 35, image_url already exists:
# https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEhJkRDjgcNzGfB-aky8bv9TxeDRIYcNCvTPYjxW9C3rikGO1Hsz5WN64SJKhsy0ZZ0IBlfA_emMKNC8PfXnh0rkvLBDYun55TCjPXPF0nIyqLi7_Ps5pigZD2R2GlgJYXfLVr6LZ_VqUDsh/s1600/ofalln+sticke.jpg
# Beer: evan altmighty, Brewery: blue mountain brewery
# Skipping row 36, image_url already exists:
# https://i.ytimg.com/vi/ORkmbFc_GZQ/hq720.jpg?sqp=-oaymwEhCK4FEIIDSFryq4qpAxMIARUAAAAAGAElAADIQj0AgKJD&rs=AOn4CLDiTbqlvXt54iNRQ_KbwlZTkOyYPg
# Beer: alterior motive, Brewery: coast brewing company
# Skipping row 37, image_url already exists:
# https://lh3.googleusercontent.com/mDlo7S8ln_iAgRKeb2idDpODrXKHcnjG8NaQ_oBM3K0c3idmlxIlTh9y7BQh_Yj5o0B5h2ZlAHFsd-1cRht1vSHTEb-xsg=s150
# Beer: the detroit dwarf, Brewery: detroit beer co.
# Skipping row 38, image_url already exists:
# https://oldnationbrewing.com/wp-content/uploads/2024/02/beer-detroit-dwarf.webp
# Beer: olde school barleywine, Brewery: dogfish head brewery
# Skipping row 39, image_url already exists:
# https://www.dogfish.com/files/media/beer/olde-school-bottling-1.jpg
# Beer: brewer's reserve bourbon barrel barleywine, Brewery: central waters brewing company
# Skipping row 40, image_url already exists:
# https://halftimebeverage.com/media/catalog/product/cache/5a9ece781d558937ae51db0fc99c94f4/rdi/rdi/brewers-reserve-french-toast-stout-39010_1.png
# Beer: old ruffian, Brewery: great divide brewing company
# Skipping row 41, image_url already exists:
# https://www.datocms-assets.com/75079/1656594559-353ad31ca8985c1f2016427d4627c4f1c002b340_great-divide-old-ruffian-barleywine-2015-10-04_bottle_review_243_hi-res.jpg?w=900
# Beer: old horizontal, Brewery: victory brewing company
# Skipping row 42, image_url already exists:
# https://cdn.beeradvocate.com/im/beers/1009.jpg
# Beer: behemoth, Brewery: three floyds brewing co. & brewpub
# Skipping row 43, image_url already exists:
# https://cdn.shopify.com/s/files/1/0044/3572/files/BABehemoth.png?v=1687206580
# Beer: olde gnarlywine, Brewery: lagunitas brewing company
# Skipping row 44, image_url already exists:
# https://i0.wp.com/absolutebeer.com/wp-content/uploads/2018/02/2018_0204_Olde_GnarlyWine_Photo.jpg?fit=640%2C640&ssl=1
# Beer: old numbskull, Brewery: alesmith brewing company
# Skipping row 45, image_url already exists:
# https://www.datocms-assets.com/75079/1656594354-7a851026a62770c337ed90451ebc7787350e13ca_alesmith-old-numbskull-barleywine-2015-10-04_bottle_review_245_hi-resjpg.jpeg?w=900
# Beer: flying mouflan, Brewery: troegs brewing company
# Skipping row 46, image_url already exists:
# https://www.twobeerdudes.com/images/beers/flying_mouflan_troegs_brewing_company.jpg
# Beer: xs old crustacean, Brewery: rogue ales
# Skipping row 47, image_url already exists:
# https://beerconnoisseur.com/sites/default/files/styles/beer_page_245w/public/beer/xs-old-crustacean.jpg?itok=84IxI0ym
# Beer: doggie claws, Brewery: hair of the dog brewing company / brewery and tasting room
# Skipping row 48, image_url already exists:
# https://images.untp.beer/resize?width=256&type=webp&url=https://halftimebeverage.com/media/catalog/product/b/a/ba-glass-2025-beer01.jpg
# Beer: helldorado, Brewery: firestone walker brewing co.
# Skipping row 49, image_url already exists:
# https://www.datocms-assets.com/75079/1656594469-01dc335d221397dc3d8c26d7ed21f85fc3aa4ea3_firestone-walker-helldorado-2015-10-04_bottle_review_202_hi-resjpg.jpeg?w=900
# Beer: cockeyed cooper, Brewery: uinta brewing company
# Skipping row 50, image_url already exists:
# https://www.wine-searcher.com/images/labels/36/76/10303676.jpg?width=175&height=234&fit=bounds&canvas=180,240
# Beer: solstice d'hiver, Brewery: brasserie dieu du ciel
# Skipping row 51, image_url already exists:
# https://cdn11.bigcommerce.com/s-41e84jdtvf/images/stencil/1280x1280/products/50759/92007/63091__06358.1706742756.jpg?c=1
# Beer: anniversary barley wine ale, Brewery: uinta brewing company
# Skipping row 52, image_url already exists:
# http://craftshack.com/cdn/shop/products/Uinta-Anniversary-Barleywine-Ale-16OZ-CAN.jpg?v=1667708131
# Beer: barleywine style ale, Brewery: green flash brewing co.
# Skipping row 53, image_url already exists:
# https://i.ebayimg.com/images/g/TtgAAOSwT5tWP28g/s-l400.jpg
# Beer: lower de boom barleywine, Brewery: 21st amendment brewery
# Skipping row 54, image_url already exists:
# https://lh4.ggpht.com/bA_iOR03qUeIOu8L0fgRvAZlULDRwHYOJrjMNXAiMW7IpDwwhKDADKrCyBUwzcWouPooAocPCkhb_lEOoT5qxRC9dV7upg=s750
# Beer: killer penguin barleywine, Brewery: boulder beer / wilderness pub
# Skipping row 55, image_url already exists:
# https://cdn.beeradvocate.com/im/beers/9845.jpg
# Beer: great, Brewery: alpine beer company
# Skipping row 56, image_url already exists:
# https://alpinebeerco.com/wp-content/uploads/2014/12/Trees_Logo_mobile3.jpg
# Beer: griffin's bowboston beer company (samuel adams), Brewery: boston beer company (samuel adams)
# Skipping row 57, image_url already exists:
# https://cdn.beeradvocate.com/im/beers/74591.jpg
# Beer: sisyphus, Brewery: real ale brewing company
# Skipping row 58, image_url already exists:
# https://realalebrewing.com/wp-content/uploads/2015/01/sisy_bottlealone.png
# Beer: gratitude, Brewery: east end brewing company
# Skipping row 59, image_url already exists:
# https://images.squarespace-cdn.com/content/v1/63d939fc2e97df6ec37c2855/1396f4d4-67a2-4a1b-aba4-1cf32c526b56/_DSC4619.jpg
# Beer: barleywine ale, Brewery: the duck-rabbit craft brewery
# Skipping row 60, image_url already exists:
# https://www.liquorstore-online.com/product_images/p_102449.jpg
# Beer: the vermonster, Brewery: rock art brewery
# Skipping row 61, image_url already exists:
# https://thebeerly.com/uploads/rock-art-vermonster.jpg
# Beer: smuttynose barleywine style ale (big beer series), Brewery: smuttynose brewing company
# Skipping row 62, image_url already exists:
# https://cdn.beeradvocate.com/im/beers/181.jpg
# Beer: john barleycorn barleywine ale, Brewery: mad river brewing company
# Skipping row 63, image_url already exists:
# https://www.datocms-assets.com/75079/1656595603-83729517f1b2d862a77edde93e89b09d703826a5_mad-river-john-barleycorn-barleywine-2015-10-04_bottle_review_189_hi-res.jpg?w=900
# Beer: barrel aged behemoth, Brewery: three floyds brewing co. & brewpub
# Skipping row 64, image_url already exists:
# https://cdn.shopify.com/s/files/1/0044/3572/files/BABehemoth.png?v=1687206580
# Beer: old ruffian - barrel-aged, Brewery: great divide brewing company
# Skipping row 65, image_url already exists:
# https://www.datocms-assets.com/75079/1656594538-8e17a6fce704342d165256dcae847e7a2aa1114d_great-divide-old-ruffian-barleywine-2015-10-04_bottle_review_193_hi-res.jpg?w=900
# Beer: # 100, Brewery: nøgne ø - det kompromissløse bryggeri a/s
# Skipping row 66, image_url already exists:
# https://upload.wikimedia.org/wikipedia/commons/e/eb/Flasker_hals.jpg
# Beer: old numbskull - bourbon barrel-aged, Brewery: alesmith brewing company
# Skipping row 67, image_url already exists:
# https://www.datocms-assets.com/75079/1656594348-0da30ebcaffde2549f8e4096d2319ba967bf5585_alesmith-ba-old-numbskull-2015-10-04_bottle_review_164_hi-resjpg.jpeg?w=900
# Beer: devil's milk, Brewery: duclaw brewing company
# Skipping row 68, image_url already exists:
# https://assets.untappd.com/photos/2023_07_16/ef9024b37394ed0be0c97fe7a870ab9a_640x640.jpg
# Beer: big worse, Brewery: mikkeller aps
# Skipping row 69, image_url already exists:
# http://craftshack.com/cdn/shop/products/Mikkeller-Big-Worse-Barley-Wine-375ML-BTL.png?v=1587205728
# Beer: chicken killer barley wine, Brewery: santa fe brewing company
# Skipping row 70, image_url already exists:
# https://santafebrewing.com/wp-content/uploads/2019/01/Chicken_Killer-420x1024.png
# Beer: olde bluehair barley wine, Brewery: big sky brewing company
# Skipping row 71, image_url already exists:
# https://www.datocms-assets.com/75079/1656594378-289d8be1d22151e1eda1c522f85c970f3e246562_big-sky-olde-bluehair-barleywine-2015-10-04_bottle_review_176_hi-resjpg.jpeg?w=900
# Beer: old blarney barleywine, Brewery: moylan's brewery
# Skipping row 72, image_url already exists:
# https://beerstreetjournal.com/wp-content/uploads/2010/02/Moylans-Old-Blarney.jpg
# Beer: druid fluid, Brewery: middle ages brewing co., ltd.
# Skipping row 73, image_url already exists:
# https://www.irondesign.com/wp-content/uploads/2020/02/DruidFluid_MOCK-e1615576832349.png
# Beer: holidale, Brewery: berkshire brewing company inc.
# Skipping row 74, image_url already exists:
# https://icdn.bottlenose.wine/images/full/748901.png?ar=1&fit=crop&crop=entropy
# Beer: old howling bastard, Brewery: blue point brewing company
# Skipping row 75, image_url already exists:
# https://assets.untappd.com/site/beer_logos_hd/beer-_14968_hd_8416821b8d06b876581bc3dd8ff325.jpeg
# Beer: old backus barleywine, Brewery: free state brewing co.
# Skipping row 76, image_url already exists:
# https://www.freestatebrewing.com/wp-content/uploads/2021/03/barleywine-bottle.png
# Beer: §ucaba, Brewery: firestone walker brewing co.
# Skipping row 77, image_url already exists:
# https://www.datocms-assets.com/75079/1656596547-7a40617d817c8ddf05a3ccc1c11482c8b0603e56_firestone-walker-sucaba-barleywine-2015-10-04_bottle_review_188_hi-res.jpg?w=900
# Beer: insanity, Brewery: weyerbacher brewing co.
# Skipping row 78, image_url already exists:
# https://halftimebeverage.com/media/catalog/product/cache/5a9ece781d558937ae51db0fc99c94f4/rdi/rdi/insanity-70138_1.png
# Beer: blithering idiot, Brewery: weyerbacher brewing co.
# Skipping row 79, image_url already exists:
# https://halftimebeverage.com/media/catalog/product/cache/5a9ece781d558937ae51db0fc99c94f4/rdi/rdi/blithering-idiot-39539_1.png
# Beer: mother of all storms, Brewery: pelican pub & brewery
# Skipping row 80, image_url already exists:
# https://pelicanbrewing.com/wp-content/uploads/2016/09/MotherStormsPour-3.png
# Beer: old foghorn, Brewery: anchor brewing company
# Skipping row 81, image_url already exists:
# http://bevmo.com/cdn/shop/products/fa11a8d5-87b2-4078-8ef6-833e0515c7d0.png?v=1701149705
# Beer: double double barrel ale, Brewery: firestone walker brewing co.
# Skipping row 82, image_url already exists:
# https://www.datocms-assets.com/75079/1672870418-firestone-walker-dba-8878.jpg?w=900
# Beer: mirror mirror, Brewery: deschutes brewery
# Skipping row 83, image_url already exists:
# http://deschutesbrewery.com/cdn/shop/files/Mirror_Pond_12oz_Can_Sweaty.webp?v=1713454669
# Beer: arctic devil barley wine, Brewery: midnight sun brewing co.
# Skipping row 84, image_url already exists:
# https://midnightsunbrewing.com/wp-content/uploads/Arctic-Devil-1-1.png
# Beer: horn dog, Brewery: flying dog brewery
# Skipping row 85, image_url already exists:
# https://cityhive-prod-cdn.cityhive.net/products/5e3c87f815b530500cf9bfd8/large.png
# Beer: bourbon barrel-aged barley wine, Brewery: kuhnhenn brewing company
# Skipping row 86, image_url already exists:
# https://tapchibeer.net/wp-content/uploads/2025/04/Chai-Bourbon-Barrel-Aged-Barley-Wine.jpg
# Beer: j.w. lees harvest ale (lagavulin whisky cask)j.w. lees & co (brewers) ltd, Brewery: j.w. lees & co (brewers) ltd
# Skipping row 87, image_url already exists:
# http://craftshack.com/cdn/shop/products/JW-Lees-Harvest-Ale-Lagavulin-Whisky-Cask-275ML-BTL.png?v=1587267236
# Beer: bligh's barleywine ale, Brewery: dry dock brewing co.
# Skipping row 88, image_url already exists:
# https://www.datocms-assets.com/75079/1672870293-dry-dock-blighs-barleywine-8910.jpg?w=900
# Beer: j.w. lees harvest ale (calvados cask)j.w. lees & co (brewers) ltd, Brewery: j.w. lees & co (brewers) ltd
# Skipping row 89, image_url already exists:
# https://cdn.beeradvocate.com/im/beers/24349.jpg
# Beer: j.w. lees harvest ale (port cask)j.w. lees & co (brewers) ltd, Brewery: j.w. lees & co (brewers) ltd
# Skipping row 90, image_url already exists:
# http://craftshack.com/cdn/shop/products/JW_Lees_Harvest_Ale_Port_Cask_275ML_BTL.jpg?v=1587267171
# Beer: ridge runner, Brewery: rock art brewery
# Skipping row 91, image_url already exists:
# https://thebeerly.com/uploads/rock-art-ridge-runner.jpg
# Beer: j.w. lees harvest ale (sherry cask)j.w. lees & co (brewers) ltd, Brewery: j.w. lees & co (brewers) ltd
# Skipping row 92, image_url already exists:
# https://cdn.beeradvocate.com/im/beers/26039.jpg
# Beer: irish walker, Brewery: olde hickory brewery
# Skipping row 93, image_url already exists:
# https://assets.untappd.com/site/beer_logos_hd/beer-19941_1d053_hd.jpeg
# Beer: criminally bad elf barleywine-style ale, Brewery: ridgeway brewing
# Skipping row 94, image_url already exists:
# https://cdn.diffords.com/contrib/bws/2017/10/59db91b581a4f.jpg
# Beer: commander, Brewery: lift bridge brewery
# Skipping row 95, image_url already exists:
# https://www.liftbridgebrewery.com/wp-content/uploads/2022/11/Commander2021-750ml.png
# Beer: pugsley's signature series: barley wine, Brewery: shipyard brewing co.
# Skipping row 96, image_url already exists:
# https://thebeerly.com/uploads/shipyard-barley-wine-style-ale-pugsleys-signature-series.jpg
# Beer: bommen & granaten, Brewery: brouwerij de molen
# Skipping row 97, image_url already exists:
# https://cdn11.bigcommerce.com/s-4dsnxp/images/stencil/500x659/products/2787/3123/De_Molen_Bommen_Granaten_Bombs_Grenades__12899.1449017825.png?c=2
# Beer: double old thumper ale, Brewery: shipyard brewing co.
# Skipping row 98, image_url already exists:
# https://boozedancing.com/wp-content/uploads/2014/05/shipyard-old-thumper.jpg
# Beer: wooden hell, Brewery: flossmoor station restaurant & brewery
# Skipping row 99, image_url already exists:
# https://thefullpint.com/wp-content/uploads/2016/08/Flossmoor-Station-Wooden-Hell.jpeg
# Beer: golden pride, Brewery: fuller smith & turner plc
# Skipping row 100, image_url already exists:
# https://www.fullersbrewery.co.uk/cdn/shop/files/FdRBOL4WAAERXhb_75c6a431-f1b2-4645-839c-8b8d674a9ff0.jpg?v=10523256349826598770
# Beer: stormwatcher's winterfest, Brewery: pelican pub & brewery
# Skipping row 101, image_url already exists:
# https://byo.com/wp-content/uploads/pelican-perfect-storm.png
# Beer: old abominable, Brewery: stoudts brewing co.
# Skipping row 102, image_url already exists:
# https://assets.untappd.com/site/beer_logos_hd/beer-5587_5d519_hd.jpeg
# Beer: fuller's esb, Brewery: fuller smith & turner plc
# Skipping row 103, image_url already exists:
# https://absolutebeer.com/wp-content/uploads/2019/08/2018-0213-Fullers-ESB-Packaging-2018.jpg
# Beer: hobgoblin ruby, Brewery: wychwood brewery company ltd
# Skipping row 104, image_url already exists:
# https://hobgoblinbeer.co.uk/wp-content/uploads/2020/04/Bottle_Ruby.jpg
# Beer: sawtooth, Brewery: left hand brewing company
# Skipping row 105, image_url already exists:
# https://9e1f107ab36932bd7899-c167113948c837617fb235faa4253299.ssl.cf2.rackcdn.com/uploads/images/full/221348eb7a0fbaacce360ac8a74f6536.png
# Beer: harvest ale, Brewery: southern tier brewing company
# Skipping row 106, image_url already exists:
# https://stbcbeer.com/wp-content/uploads/2019/08/STBC_Harvest_12oz_Can_Render-2002x3633-a39638b.png
# Beer: old thumper, Brewery: shipyard brewing co.
# Skipping row 107, image_url already exists:
# https://i.ebayimg.com/images/g/S0YAAOSwKGNhczF8/s-l1200.jpg
# Beer: abbot ale, Brewery: greene king / morland brewery
# Skipping row 108, image_url already exists:
# http://www.brewgene.com/sites/default/files/beer_images/user65943_46769_1546437139.jpg
# Beer: anvil, Brewery: alesmith brewing company
# Skipping row 109, image_url already exists:
# https://alesmith.com/wp-content/uploads/2024/12/Anvil-Pilsner-12oz_OurBeers-2.png
# Beer: scarlet lady ale, Brewery: stoudts brewing co.
# Skipping row 110, image_url already exists:
# https://assets.untappd.com/site/beer_logos_hd/beer-3877_94e2c_hd.jpeg
# Beer: lord rear admiral, Brewery: three floyds brewing co. & brewpub
# Skipping row 111, image_url already exists:
# https://beerpulse.com/wp-content/uploads/2012/12/Three-Floyds-Lord-Rear-Admiral-ESB.png
# Beer: extra special ale (esa), Brewery: yards brewing co.
# Skipping row 112, image_url already exists:
# https://assets.untappd.com/site/beer_logos_hd/beer-4972_a1f85_hd.jpeg
# Beer: foster's premium ale, Brewery: foster's group limited
# Skipping row 113, image_url already exists:
# https://www.luekensliquors.com/wp-content/uploads/2018/10/FOSTERS-PREMIUM-25OZ-CN-25OZ-Beer.png
# Beer: belk's esb, Brewery: anderson valley brewing company
# Skipping row 114, image_url already exists:
# https://i.ebayimg.com/images/g/5VoAAOSwyNFa06Xs/s-l1200.jpg
# Beer: esb, Brewery: green man brewery
# Skipping row 115, image_url already exists:
# https://assets.untappd.com/site/beer_logos_hd/beer-15981_6f6bd_hd.jpeg
# Beer: motor boat, Brewery: sweetwater brewing company
# Skipping row 116, image_url already exists:
# http://brewbound-images.s3.amazonaws.com/wp-content/uploads/2013/08/Motor-Boat-Compressed.jpg
# Beer: esb special ale, Brewery: ska brewing co.
# Skipping row 117, image_url already exists:
# https://thebeerly.com/uploads/ska-esb-special-ale.jpg
# Beer: autumn ale, Brewery: short's brewing company
# Skipping row 118, image_url already exists:
# https://www.shortsbrewing.com/wp-content/uploads/2022/08/AutumnAle_web2018_1523984856.jpg
# Beer: halloween ale, Brewery: gritty mcduff's brewing company
# Skipping row 119, image_url already exists:
# https://images.untp.beer/crop?width=640&height=640&stripmeta=true&url=https://untappd.s3.amazonaws.com/photos/2024_10_31/d3ac3c8a186510fdfd14ae0e015d8c17_c_1429871432_raw.jpg
# Beer: bishops finger, Brewery: shepherd neame ltd
# Error at row 120: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=bishops+finger+shepherd+neame+ltd+beer&cx=f2200e4199149422d&key=AIzaSyDTcdOfCqA9AXjNJe4-vAf97xW2FeTt_f0&searchType=image&num=5
# Saving 3197 image URLs to S3...
# Done! Saved to s3://itam-analytics-thmrudolf/final_project/clean/beer_names_breweries_with_images.csv

# %%
from sagemaker.sklearn.processing import SKLearnProcessor
from sagemaker.processing import ProcessingInput, ProcessingOutput
from sagemaker import get_execution_role
import sagemaker
import boto3

role = get_execution_role()
region = "us-east-1"
bucket = "itam-analytics-thmrudolf"
S3_KEY = "final_project/clean/beer_names_breweries_with_images.csv"
output_path = f"s3://{bucket}/{S3_KEY}/"

sklearn_processor = SKLearnProcessor(
    framework_version="1.2-1",
    role=role,
    instance_type="ml.m5.large",
    instance_count=1,
    base_job_name="csv-image-finder-job"
)

sklearn_processor.run(
    code="pipeline_actualization_images.py",
    outputs=[
        ProcessingOutput(source="/opt/ml/processing/output", destination=output_path)
    ]
)
# Out:
# INFO:sagemaker:Creating processing-job with name csv-image-finder-job-2025-05-27-02-50-02-261
# ...............
# ..

# %%
from sagemaker.workflow.parameters import (
    ParameterInteger,
    ParameterString,
    ParameterFloat,
)

processing_instance_count = ParameterInteger(name="ProcessingInstanceCount", default_value=1)
instance_type = ParameterString(name="FindingNewImageUrls", default_value="ml.m5.xlarge")
model_approval_status = ParameterString(
    name="ApprovalStatus", default_value="PendingManualApproval"
)
input_data = ParameterString(
    name="InputData",
    default_value=input_data_uri,
)
#batch_data = ParameterString(
#    name="BatchData",
#    default_value=batch_data_uri,
#)
#mse_threshold = ParameterFloat(name="MseThreshold", default_value=6.0)

# %%
from sagemaker.workflow.pipeline import Pipeline
from sagemaker.workflow.steps import ProcessingStep
from sagemaker.sklearn.processing import SKLearnProcessor
from sagemaker.session import Session
from sagemaker import get_execution_role

role = get_execution_role()
sagemaker_session = Session()

sklearn_processor = SKLearnProcessor(
    framework_version="1.2-1",
    role=role,
    instance_type="ml.m5.large",
    instance_count=1
)

step_process = ProcessingStep(
    name="GenerateCSVStep",
    processor=sklearn_processor,
    code="pipeline_actualization_images.py",
    outputs=[]
)

pipeline = Pipeline(
    name="DailyCsvPipeline",
    steps=[step_process],
    sagemaker_session=sagemaker_session
)
# Out:
# INFO:sagemaker.image_uris:Defaulting to only available Python version: py3

# %%
pipeline.upsert(role_arn=role)
# Out:
# WARNING:sagemaker.workflow.utilities:Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# {'PipelineArn': 'arn:aws:sagemaker:us-east-1:535002863660:pipeline/DailyCsvPipeline',
#  'ResponseMetadata': {'RequestId': 'f07299ad-dfc5-44f0-8cb3-e88cb650f325',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'f07299ad-dfc5-44f0-8cb3-e88cb650f325',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '84',
#    'date': 'Sun, 25 May 2025 16:59:40 GMT'},
#   'RetryAttempts': 0}}

# %%
execution = pipeline.start()
print(execution)
# Out:
# _PipelineExecution(arn='arn:aws:sagemaker:us-east-1:535002863660:pipeline/DailyCsvPipeline/execution/nm2rad1kkfu3', sagemaker_session=<sagemaker.session.Session object at 0x7fe2002a22a0>)

# %%
execution.describe()
# Out:
# {'PipelineArn': 'arn:aws:sagemaker:us-east-1:535002863660:pipeline/DailyCsvPipeline',
#  'PipelineExecutionArn': 'arn:aws:sagemaker:us-east-1:535002863660:pipeline/DailyCsvPipeline/execution/53ucogcwao0a',
#  'PipelineExecutionDisplayName': 'execution-1748192401909',
#  'PipelineExecutionStatus': 'Executing',
#  'PipelineExperimentConfig': {'ExperimentName': 'dailycsvpipeline',
#   'TrialName': '53ucogcwao0a'},
#  'CreationTime': datetime.datetime(2025, 5, 25, 17, 0, 1, 806000, tzinfo=tzlocal()),
#  'LastModifiedTime': datetime.datetime(2025, 5, 25, 17, 0, 1, 806000, tzinfo=tzlocal()),
#  'CreatedBy': {'UserProfileArn': 'arn:aws:sagemaker:us-east-1:535002863660:user-profile/d-a0uxfxrem9gp/datascientist',
#   'UserProfileName': 'datascientist',
#   'DomainId': 'd-a0uxfxrem9gp',
#   'IamIdentity': {'Arn': 'arn:aws:sts::535002863660:assumed-role/SageMakerStudioExecutionRole/SageMaker',
#    'PrincipalId': 'AROAXZEFH3AWBZL57IMHS:SageMaker'}},
#  'LastModifiedBy': {'UserProfileArn': 'arn:aws:sagemaker:us-east-1:535002863660:user-profile/d-a0uxfxrem9gp/datascientist',
#   'UserProfileName': 'datascientist',
#   'DomainId': 'd-a0uxfxrem9gp',
#   'IamIdentity': {'Arn': 'arn:aws:sts::535002863660:assumed-role/SageMakerStudioExecutionRole/SageMaker',
#    'PrincipalId': 'AROAXZEFH3AWBZL57IMHS:SageMaker'}},
#  'ResponseMetadata': {'RequestId': 'af2b02da-72b6-447b-8ed2-b691ebc038f8',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'af2b02da-72b6-447b-8ed2-b691ebc038f8',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '1115',
#    'date': 'Sun, 25 May 2025 17:00:05 GMT'},
#   'RetryAttempts': 0}}

# %%
execution.list_steps()
# Out:
# [{'StepName': 'GenerateCSVStep',
#   'StartTime': datetime.datetime(2025, 5, 25, 17, 0, 2, 777000, tzinfo=tzlocal()),
#   'StepStatus': 'Executing',
#   'Metadata': {'ProcessingJob': {'Arn': 'arn:aws:sagemaker:us-east-1:535002863660:processing-job/pipelines-53ucogcwao0a-GenerateCSVStep-G0JPp6sz7q'}},
#   'AttemptCount': 1}]
